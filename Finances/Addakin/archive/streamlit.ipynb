# %%
pip install streamlit pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: streamlit in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (1.42.2)
# Requirement already satisfied: pandas in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (2.2.3)
# Requirement already satisfied: click<9,>=7.0 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from streamlit) (8.1.8)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from streamlit) (9.0.0)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: numpy<3,>=1.23 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from streamlit) (2.0.2)
# Requirement already satisfied: blinker<2,>=1.0.0 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from streamlit) (5.29.3)
# Requirement already satisfied: cachetools<6,>=4.0 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from streamlit) (5.5.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from streamlit) (11.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: toml<2,>=0.10.1 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: tornado<7,>=6.0.3 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from streamlit) (6.4.2)
# Requirement already satisfied: altair<6,>=4.0 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: pyarrow>=7.0 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from streamlit) (19.0.1)
# Requirement already satisfied: packaging<25,>=20 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from streamlit) (24.2)
# Requirement already satisfied: rich<14,>=10.14.0 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from streamlit) (13.9.4)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from streamlit) (3.1.44)
# Requirement already satisfied: pytz>=2020.1 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from pandas) (2025.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from pandas) (2025.1)
# Requirement already satisfied: jinja2 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from altair<6,>=4.0->streamlit) (3.1.5)
# Requirement already satisfied: narwhals>=1.14.2 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from altair<6,>=4.0->streamlit) (1.27.1)
# Requirement already satisfied: jsonschema>=3.0 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: referencing>=0.28.4 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: attrs>=22.2.0 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (25.1.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.23.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2024.10.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: six>=1.5 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.27->streamlit) (3.4.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.27->streamlit) (2025.1.31)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.27->streamlit) (2.3.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from rich<14,>=10.14.0->streamlit) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# WARNING: You are using pip version 21.2.4; however, version 25.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (3.9.4)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: cycler>=0.10 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: packaging>=20.0 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: numpy>=1.23 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: pillow>=8 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: zipp>=3.1.0 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.21.0)
# Requirement already satisfied: six>=1.5 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# WARNING: You are using pip version 21.2.4; however, version 25.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: openai in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (1.64.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from openai) (4.8.0)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from openai) (4.12.2)
# Requirement already satisfied: sniffio in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from openai) (4.67.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from openai) (0.8.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from openai) (0.28.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from openai) (1.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from openai) (2.10.6)
# Requirement already satisfied: idna>=2.8 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: httpcore==1.* in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: certifi in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/addakinthomas/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1.9.0->openai) (2.27.2)
# WARNING: You are using pip version 21.2.4; however, version 25.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import os

# Define file path
desktop_folder = os.path.expanduser("/Users/addakinthomas/Desktop/Finances/Data")
csv_file = os.path.join(desktop_folder, "curated_finances.csv")  # Change filename

# Load the CSV
df = pd.read_csv(csv_file)
df.head()  # Display first 5 rows
# Out:
#                                   Description  Amount  \
# 0                                        UBER   16.39
# 1                                        UBER   20.93
# 2  Interest Charge on Pay Over Time Purchases   43.88
# 3  TST* MIKE'S BEER BARPITTSBURGH          PA    3.67
# 4                                        UBER   14.96
#
#                  Appears On Your Statement As         City/State  \
# 0  AplPay Uber Trip    help.uber.com       CA  SAN FRANCISCO\nCA
# 1  AplPay Uber Trip    help.uber.com       CA  SAN FRANCISCO\nCA
# 2  Interest Charge on Pay Over Time Purchases                NaN
# 3  TST* MIKE'S BEER BARPITTSBURGH          PA     PITTSBURGH\nPA
# 4  AplPay Uber Trip    help.uber.com       CA  SAN FRANCISCO\nCA
#
#                                 Category     Month  Day     Parent Category  \
# 0           Transportation-Taxis & Coach  February    9      Transportation
# 1           Transportation-Taxis & Coach  February    9      Transportation
# 2  Fees & Adjustments-Fees & Adjustments  February    9  Fees & Adjustments
# 3                  Restaurant-Bar & Café  February    9       Food & Drinks
# 4           Transportation-Taxis & Coach  February    8      Transportation
#
#   Account
# 0    AMEX
# 1    AMEX
# 2    AMEX
# 3    AMEX
# 4    AMEX

# %% [markdown]
# # %%writefile app.py

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd
import os
import matplotlib.pyplot as plt

# Define file path dynamically
desktop_folder = os.path.expanduser("~/Desktop/Finances/Data")
csv_file = os.path.join(desktop_folder, "curated_finances.csv")

# Load CSV data safely
def load_data():
    try:
        df = pd.read_csv(csv_file)
        return df
    except FileNotFoundError:
        return None

# Streamlit UI
st.set_page_config(layout="wide")
st.title("📊 Addakin's Financial Overview")

# Load data
df = load_data()

if df is None:
    st.error(f"❌ CSV file not found at: `{csv_file}`")
else:
    # Normalize column names to lowercase for consistency
    df.columns = df.columns.str.lower()
    
    # Sidebar with non-collapsable checkboxes ordered by December, January, February
    st.sidebar.header("📅 Filter by Month")
    months_ordered = ["December", "January", "February"]
    available_months = [month for month in months_ordered if month.lower() in df['month'].dropna().str.lower().unique()]
    selected_month = st.sidebar.radio("Select a month", available_months)
    
    if selected_month:
        df = df[df['month'].str.lower() == selected_month.lower()]
    
    # Move Peer-to-Peer Payments and Other - Miscellaneous to 'Other' category
    if 'category' in df.columns:
        df.loc[df['category'].str.lower().isin(['peer-to-peer payment', 'other - miscellaneous']), 'category'] = 'Other'
    
    # Separate Uncategorized Transactions
    if 'category' in df.columns:
        uncategorized_df = df[df['category'].str.lower() == 'other']
        df = df[df['category'].str.lower() != 'other']
    else:
        uncategorized_df = pd.DataFrame()
    
    # Create Tabs
    tab1, tab2, tab3 = st.tabs(["💸 Spending", "💰 Saving", "❓ Uncategorized Transactions"])
    
    with tab1:
        st.subheader("📊 Spending by Category")
        if 'category' in df.columns and 'amount' in df.columns:
            category_spending = df.groupby('category')['amount'].sum().sort_values()
            fig, ax = plt.subplots()
            bars = ax.barh(category_spending.index, category_spending.values)
            ax.set_xlabel("Total Spending ($)")
            ax.set_ylabel("Category")
            ax.set_title("Spending by Category")
            
            # Add labels to bars
            for bar in bars:
                ax.text(bar.get_width(), bar.get_y() + bar.get_height()/2, f"${bar.get_width():,.2f}", va='center')
            
            st.pyplot(fig)
        else:
            st.warning("⚠️ Missing 'Category' or 'Amount' column in data.")
        
        st.subheader("💰 Top 10 Purchases Overview")
        if 'description' in df.columns and 'amount' in df.columns:
            top_purchases = df[df['amount'] < 0][['description', 'amount']].copy()
            top_purchases = top_purchases.nsmallest(10, 'amount')
            
            fig, ax = plt.subplots()
            bars = ax.barh(top_purchases['description'], abs(top_purchases['amount']))
            ax.set_xlabel("Amount ($)")
            ax.set_ylabel("Description")
            ax.set_title("Top 10 Purchases")
            
            for bar in bars:
                ax.text(bar.get_width(), bar.get_y() + bar.get_height()/2, f"${bar.get_width():,.2f}", va='center')
            
            st.pyplot(fig)
        else:
            st.warning("⚠️ Missing 'Description' or 'Amount' column in data.")
    
    with tab2:
        st.subheader("💰 Savings Overview")
        if 'savings_category' in df.columns and 'savings_amount' in df.columns:
            savings_summary = df.groupby('savings_category')['savings_amount'].sum().sort_values()
            fig, ax = plt.subplots()
            bars = ax.barh(savings_summary.index, savings_summary.values)
            ax.set_xlabel("Total Savings ($")
            ax.set_ylabel("Category")
            ax.set_title("Savings by Category")
            
            for bar in bars:
                ax.text(bar.get_width(), bar.get_y() + bar.get_height()/2, f"${bar.get_width():,.2f}", va='center')
            
            st.pyplot(fig)
        else:
            st.warning("⚠️ No savings data found in the dataset.")
    
    with tab3:
        st.subheader("❓ Uncategorized Transactions")
        if not uncategorized_df.empty:
            st.dataframe(uncategorized_df)
        else:
            st.warning("⚠️ No uncategorized transactions found.")
    
    # Feedback Section
    st.subheader("💡 Feedback & Suggestions")
    feedback_text = st.text_area("How can we improve this dashboard?")
    if st.button("Submit Feedback"):
        with open("feedback.txt", "a") as f:
            f.write(feedback_text + "\n")
        st.success("✅ Thank you for your feedback!")
# Out:
# Overwriting app.py
